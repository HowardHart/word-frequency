# %%
# -*- coding: utf-8 -*-
"""
Word Frequency Counter

A simple Python script to count word frequencies in a text file.

Features:
- Read text file (.txt)
- Clean text (lowercase, remove punctuation)
- Tokenize and count word frequencies
- Display top N frequent words
- Calculate token count (total words)
- Calculate type count (unique words)
- Calculate type/token ratio (TTR)
- Export results to CSV
Usage:
    python word_frequency.py

Requires:
    Python 3.x
    pandas

Input:  .txt file (default: sample.txt)
Output: .csv file (default: word_frequency.csv)

Author: HowardHart
Date:   2024-09-02
"""

import re
import pandas as pd
from collections import Counter

# ==================== 1. Read text file ====================
def read_text(file_path):
    """
    Read the content of a text file and return as a string.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            text = file.read()
        print(f"Successfully read file: {file_path}")
        return text
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        return None

# ==================== 2. Clean text ====================
def clean_text(text):
    """
    Clean the text: convert to lowercase, remove punctuation.
    Keeps only letters, digits, and whitespace.
    """
    text = text.lower()
    # Keep only alphanumeric characters and spaces
    text = re.sub(r'[^a-z0-9\s]', '', text)
    return text

# ==================== 3. Tokenize ====================
def tokenize(text):
    """
    Split cleaned text into a list of words.
    """
    words = text.split()
    # Filter out empty strings
    words = [w for w in words if w]
    return words

# ==================== 4. Count word frequency ====================
def count_word_frequency(words):
    """
    Count frequency of each word using Counter.
    Returns a Counter object.
    """
    return Counter(words)

# ==================== 5. Get top N words ====================
def get_top_words(counter, n=20):
    """
    Return the top N most frequent words.
    """
    return counter.most_common(n)

# ==================== 6. Save results to CSV ====================
def save_to_csv(counter, output_path):
    """
    Save word frequency results to a CSV file.
    """
    df = pd.DataFrame(counter.items(), columns=['Word', 'Frequency'])
    df = df.sort_values(by='Frequency', ascending=False)
    df.to_csv(output_path, index=False, encoding='utf-8-sig')
    print(f"Results saved to: {output_path}")

# ==================== Main program ====================
def main():
    # Configuration
    input_file = "sample.txt"           ##### Please input your text file here. #####
    output_file = "word_frequency.csv"  ##### Results will be output through a CSV file under the same folder as the program file. #####
    top_n = 100                         ##### You may change the number of top frequent words to display here. #####

    # 1. Read text
    text = read_text(input_file)
    if text is None:
        return

    # 2. Clean text
    cleaned_text = clean_text(text)

    # 3. Tokenize
    words = tokenize(cleaned_text)
    token_count = len(words)                  
    print(f"Token count (total words): {token_count}")

    # 4. Count frequency
    counter = count_word_frequency(words)
    type_count = len(counter)                  
    print(f"Type count (unique words): {type_count}")
    print(f"Type/Token ratio: {type_count/token_count:.2%}") 

    # 5. Display top words
    top_words = get_top_words(counter, top_n)
    print(f"\n Top {top_n} most frequent words:")
    for word, freq in top_words:
        print(f"  {word}: {freq}")

    # 6. Save results
    save_to_csv(counter, output_file)

    print("\n Word frequency analysis complete!")

if __name__ == "__main__":
    main()
# Out:
# Successfully read file: NR/2016/NR_2016_1.txt
# Token count (total words): 537
# Type count (unique words): 267
# Type/Token ratio: 49.72%
#
#  Top 100 most frequent words:
#   the: 36
#   to: 16
#   and: 14
#   in: 13
#   of: 12
#   chinese: 12
#   as: 10
#   boats: 10
#   fishing: 9
#   a: 8
#   china: 7
#   that: 6
#   has: 6
#   chinas: 6
#   crimea: 5
#   japan: 5
#   fleet: 5
#   little: 4
#   green: 4
#   be: 4
#   japans: 4
#   an: 4
#   with: 4
#   coast: 4
#   is: 4
#   will: 4
#   waters: 4
#   russian: 3
#   they: 3
#   men: 3
#   had: 3
#   been: 3
#   islands: 3
#   senkakus: 3
#   sea: 3
#   claim: 3
#   them: 3
#   on: 3
#   which: 3
#   eez: 3
#   guard: 3
#   vietnamese: 3
#   treaty: 3
#   president: 2
#   putin: 2
#   were: 2
#   he: 2
#   said: 2
#   after: 2
#   also: 2
#   beijing: 2
#   or: 2
#   part: 2
#   territory: 2
#   way: 2
#   theyve: 2
#   hong: 2
#   south: 2
#   already: 2
#   are: 2
#   200: 2
#   its: 2
#   exclusive: 2
#   it: 2
#   into: 2
#   armed: 2
#   ships: 2
#   branch: 2
#   military: 2
#   by: 2
#   force: 2
#   have: 2
#   interdicted: 2
#   harassed: 2
#   indonesian: 2
#   malaysian: 2
#   philippine: 2
#   sunk: 2
#   but: 2
#   rammed: 2
#   fear: 2
#   this: 2
#   either: 2
#   war: 2
#   american: 2
#   we: 2
#   if: 2
#   over: 2
#   vladimir: 1
#   denied: 1
#   greenfatigued: 1
#   insigniafree: 1
#   soldiers: 1
#   who: 1
#   popped: 1
#   up: 1
#   only: 1
#   local: 1
#   selfdefense: 1
#   forces: 1
# Results saved to: word_frequency.csv
#
#  Word frequency analysis complete!
